# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-944ea86a-a107-499d-82f2-d7b3a4f785be" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-944ea86a-a107-499d-82f2-d7b3a4f785be">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("/content/Hopsital Dataset.csv")

# %%
df
# Out:
#     Age   Date of Data Entry  Gender  \
# 0    85  19/12/2019 14:41:49  Female
# 1    87  19/12/2019 16:35:25  Female
# 2    82  19/12/2019 15:48:49    Male
# 3    82  19/12/2019 15:50:33    Male
# 4    82  19/12/2019 15:52:20    Male
# ..   ..                  ...     ...
# 828  48  19/12/2019 15:41:27  Female
# 829  15  19/12/2019 16:14:56    Male
# 830  15  19/12/2019 16:16:04    Male
# 831  15  19/12/2019 16:17:40    Male
# 832  85  19/12/2019 14:41:49  Female
#
#                                              Diagnosis  Name of Drug  \
# 0          ccf, hypertension, ida, ckd(stage 5), ?icm,   ceftriaxone
# 1             pad(lt u.l), be amputation,/post op, akt   ceftriaxone
# 2                         type-2dm, ihd, col, copd, ht     ofloxacin
# 3                        type-2 dm, ihd, col, copd, ht      cefipime
# 4                        type-2 dm, ihd, col, copd, ht  azithromycin
# ..                                                 ...           ...
# ...

# %%
df.shape
# Out:
# (833, 10)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 833 entries, 0 to 832
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Age                 833 non-null    object
#  1   Date of Data Entry  833 non-null    object
#  2   Gender              833 non-null    object
#  3   Diagnosis           833 non-null    object
#  4   Name of Drug        833 non-null    object
#  5   Dosage (gram)       833 non-null    object
#  6   Route               833 non-null    object
#  7   Frequency           833 non-null    object
#  8   Duration (days)     833 non-null    object
#  9   Indication          832 non-null    object
# dtypes: object(10)
# memory usage: 65.2+ KB

# %%
df.describe
# Out:
# <bound method NDFrame.describe of     Age   Date of Data Entry  Gender  \
# 0    85  19/12/2019 14:41:49  Female
# 1    87  19/12/2019 16:35:25  Female
# 2    82  19/12/2019 15:48:49    Male
# 3    82  19/12/2019 15:50:33    Male
# 4    82  19/12/2019 15:52:20    Male
# ..   ..                  ...     ...
# 828  48  19/12/2019 15:41:27  Female
# 829  15  19/12/2019 16:14:56    Male
# 830  15  19/12/2019 16:16:04    Male
# 831  15  19/12/2019 16:17:40    Male
# 832  85  19/12/2019 14:41:49  Female
#
#                                              Diagnosis  Name of Drug  \
# 0          ccf, hypertension, ida, ckd(stage 5), ?icm,   ceftriaxone
# 1             pad(lt u.l), be amputation,/post op, akt   ceftriaxone
# 2                         type-2dm, ihd, col, copd, ht     ofloxacin
# 3                        type-2 dm, ihd, col, copd, ht      cefipime
# 4                        type-2 dm, ihd, col, copd, ht  azithromycin
# ...

# %%
df.head()
# Out:
#   Age   Date of Data Entry  Gender  \
# 0  85  19/12/2019 14:41:49  Female
# 1  87  19/12/2019 16:35:25  Female
# 2  82  19/12/2019 15:48:49    Male
# 3  82  19/12/2019 15:50:33    Male
# 4  82  19/12/2019 15:52:20    Male
#
#                                      Diagnosis  Name of Drug Dosage (gram)  \
# 0  ccf, hypertension, ida, ckd(stage 5), ?icm,   ceftriaxone             1
# 1     pad(lt u.l), be amputation,/post op, akt   ceftriaxone             1
# 2                 type-2dm, ihd, col, copd, ht     ofloxacin           0.4
# 3                type-2 dm, ihd, col, copd, ht      cefipime             1
# 4                type-2 dm, ihd, col, copd, ht  azithromycin           0.5
#
#   Route Frequency Duration (days)                        Indication
# 0    IV        BD               7                               icm
# 1    IV        BD               1                           post op
# 2    IV        BD               3  abd distension with leg swelling
# ...

# %%
df.head(10)
# Out:
#   Age   Date of Data Entry  Gender  \
# 0  85  19/12/2019 14:41:49  Female
# 1  87  19/12/2019 16:35:25  Female
# 2  82  19/12/2019 15:48:49    Male
# 3  82  19/12/2019 15:50:33    Male
# 4  82  19/12/2019 15:52:20    Male
# 5  82  19/12/2019 15:53:30    Male
# 6  55  19/12/2019 16:00:41  Female
# 7  55  19/12/2019 16:02:32  Female
# 8  57  19/12/2019 16:28:56    Male
# 9  57  19/12/2019 16:31:43    Male
#
#                                            Diagnosis  Name of Drug  \
# 0        ccf, hypertension, ida, ckd(stage 5), ?icm,   ceftriaxone
# 1           pad(lt u.l), be amputation,/post op, akt   ceftriaxone
# 2                       type-2dm, ihd, col, copd, ht     ofloxacin
# 3                      type-2 dm, ihd, col, copd, ht      cefipime
# 4                      type-2 dm, ihd, col, copd, ht  azithromycin
# 5                      type-2 dm, ihd, col, copd, ht   ceftazidime
# 6                                             abd tb   ceftriaxone
# ...

# %%
df.tail()
# Out:
#     Age   Date of Data Entry  Gender  \
# 828  48  19/12/2019 15:41:27  Female
# 829  15  19/12/2019 16:14:56    Male
# 830  15  19/12/2019 16:16:04    Male
# 831  15  19/12/2019 16:17:40    Male
# 832  85  19/12/2019 14:41:49  Female
#
#                                              Diagnosis Name of Drug  \
# 828                                  he,  rvi with col    rifaximin
# 829  glandular fever, measles, viral encephalitis, ...  ceftriaxone
# 830  glandular fever, measles, viral encephalitis, ...     cefixime
# 831  glandular fever, measles, viral encephalitis, ...  ceftriaxone
# 832        ccf, hypertension, ida, ckd(stage 5), ?icm,  ceftriaxone
#
#     Dosage (gram) Route Frequency Duration (days)          Indication
# 828          0.55  Oral        BD               1                 vil
# 829             2    IV        BD               2  viral encephalitis
# 830           0.2  Oral        BD               1  viral encephalitis
# ...

# %%
df.tail(10)
# Out:
#     Age   Date of Data Entry  Gender  \
# 823  46  19/12/2019 16:07:35    Male
# 824  46  19/12/2019 16:08:44    Male
# 825  56  19/12/2019 14:44:46    Male
# 826  56  19/12/2019 14:45:59    Male
# 827  76  19/12/2019 15:29:02    Male
# 828  48  19/12/2019 15:41:27  Female
# 829  15  19/12/2019 16:14:56    Male
# 830  15  19/12/2019 16:16:04    Male
# 831  15  19/12/2019 16:17:40    Male
# 832  85  19/12/2019 14:41:49  Female
#
#                                              Diagnosis  Name of Drug  \
# 823                    early col, uti, chest infection   ceftriaxone
# 824                    early col, uti, chest infection      cefixime
# 825                     uti, type 2 dm, ihd, hbs ag(+)   ceftriaxone
# 826                     uti, type 2 dm, ihd, hbs ag(+)  levofloxacin
# 827  uti,  operated spinal cord,  hematoma and para...  levofloxacin
# 828                                  he,  rvi with col     rifaximin
# ...

# %%
df.count
# Out:
# <bound method DataFrame.count of     Age   Date of Data Entry  Gender  \
# 0    85  19/12/2019 14:41:49  Female
# 1    87  19/12/2019 16:35:25  Female
# 2    82  19/12/2019 15:48:49    Male
# 3    82  19/12/2019 15:50:33    Male
# 4    82  19/12/2019 15:52:20    Male
# ..   ..                  ...     ...
# 828  48  19/12/2019 15:41:27  Female
# 829  15  19/12/2019 16:14:56    Male
# 830  15  19/12/2019 16:16:04    Male
# 831  15  19/12/2019 16:17:40    Male
# 832  85  19/12/2019 14:41:49  Female
#
#                                              Diagnosis  Name of Drug  \
# 0          ccf, hypertension, ida, ckd(stage 5), ?icm,   ceftriaxone
# 1             pad(lt u.l), be amputation,/post op, akt   ceftriaxone
# 2                         type-2dm, ihd, col, copd, ht     ofloxacin
# 3                        type-2 dm, ihd, col, copd, ht      cefipime
# 4                        type-2 dm, ihd, col, copd, ht  azithromycin
# ...

# %%
df.columns
# Out:
# Index(['Age', 'Date of Data Entry', 'Gender', 'Diagnosis', 'Name of Drug',
#        'Dosage (gram)', 'Route', 'Frequency', 'Duration (days)', 'Indication'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Age                   object
# Date of Data Entry    object
# Gender                object
# Diagnosis             object
# Name of Drug          object
# Dosage (gram)         object
# Route                 object
# Frequency             object
# Duration (days)       object
# Indication            object
# dtype: object

# %%
df.empty
# Out:
# False

# %%
df.Gender
# Out:
# 0      Female
# 1      Female
# 2        Male
# 3        Male
# 4        Male
#         ...
# 828    Female
# 829      Male
# 830      Male
# 831      Male
# 832    Female
# Name: Gender, Length: 833, dtype: object

# %%
df.Indication
# Out:
# 0                                   icm
# 1                               post op
# 2      abd distension with leg swelling
# 3      abd distension with leg swelling
# 4      abd distension with leg swelling
#                      ...
# 828                                 vil
# 829                  viral encephalitis
# 830                  viral encephalitis
# 831                  viral encephalitis
# 832                                 NaN
# Name: Indication, Length: 833, dtype: object

# %%
df.dtypes
# Out:
# Age                   object
# Date of Data Entry    object
# Gender                object
# Diagnosis             object
# Name of Drug          object
# Dosage (gram)         object
# Route                 object
# Frequency             object
# Duration (days)       object
# Indication            object
# dtype: object

# %%
df.Route
# Out:
# 0        IV
# 1        IV
# 2        IV
# 3        IV
# 4      Oral
#        ...
# 828    Oral
# 829      IV
# 830    Oral
# 831      IV
# 832      IV
# Name: Route, Length: 833, dtype: object

# %%
df.Age
# Out:
# 0      85
# 1      87
# 2      82
# 3      82
# 4      82
#        ..
# 828    48
# 829    15
# 830    15
# 831    15
# 832    85
# Name: Age, Length: 833, dtype: object
